# %% [markdown]
# ## Clustering

# %%
import anoapycore as ap

# %%
ap.version()
# Out:
# '0.1.11'

# %%
# Original file : https://www.kaggle.com/shwetabh123/mall-customers
v_data = ap.data.load.csv("D:/_data/mall_customers/mall_customers.csv")

# %%
ap.data.sample(v_data)
# Out:
#    CustomerID   Genre  Age  AnnualIncome  SpendingScore
# 0           1    Male   19            15             39
# 1           2    Male   21            15             81
# 2           3  Female   20            16              6
# 3           4  Female   23            16             77
# 4           5  Female   31            17             40

# %%
ap.data.dimension(v_data)
# Out:
# 200 rows x 5 columns

# %%
ap.data.null.count(v_data)
# Out:
# CustomerID       0
# Genre            0
# Age              0
# AnnualIncome     0
# SpendingScore    0
# dtype: int64

# %%
ap.data.stat.desc(v_data)
# Out:
#        CustomerID         Age  AnnualIncome  SpendingScore
# count  200.000000  200.000000    200.000000     200.000000
# mean   100.500000   38.850000     60.560000      50.200000
# std     57.879185   13.969007     26.264721      25.823522
# min      1.000000   18.000000     15.000000       1.000000
# 25%     50.750000   28.750000     41.500000      34.750000
# 50%    100.500000   36.000000     61.500000      50.000000
# 75%    150.250000   49.000000     78.000000      73.000000
# max    200.000000   70.000000    137.000000      99.000000

# %%
v_model = ap.mlearn.clustering.kmeans.run(v_data,['Age','AnnualIncome','SpendingScore'])

# %%
v_model.optimum_k
# Out:
# 4

# %%
v_model.elbow_chart

# %%
v_model.sse
# Out:
# [308812.7800000001,
#  212840.16982097193,
#  143342.75157170597,
#  104366.151455562,
#  75350.77917248776,
#  58300.443321590676,
#  51116.98694463434,
#  44344.949801777206,
#  40910.15994722369,
#  37429.23936176268]

# %%
v_model.clusters
# Out:
#    Cluster
# 0        0
# 1        1
# 2        2
# 3        3

# %%
v_model.centroids
# Out:
#          Age  AnnualIncome  SpendingScore
# 0  44.894737     48.705263      42.631579
# 1  40.394737     87.000000      18.631579
# 2  24.821429     28.714286      74.250000
# 3  32.692308     86.538462      82.128205

# %%
v_model.prediction
# Out:
#      __cluster
# 0            2
# 1            2
# 2            0
# 3            2
# 4            0
# ..         ...
# 195          3
# 196          1
# 197          3
# 198          1
# 199          3
#
# [200 rows x 1 columns]

# %%
v_model.worksheet
# Out:
#      CustomerID   Genre  Age  AnnualIncome  SpendingScore  __cluster
# 0             1    Male   19            15             39          2
# 1             2    Male   21            15             81          2
# 2             3  Female   20            16              6          0
# 3             4  Female   23            16             77          2
# 4             5  Female   31            17             40          0
# ..          ...     ...  ...           ...            ...        ...
# 195         196  Female   35           120             79          3
# 196         197  Female   45           126             28          1
# 197         198    Male   32           126             74          3
# 198         199    Male   32           137             18          1
# 199         200    Male   30           137             83          3
#
# [200 rows x 6 columns]

# %%
ap.data.save.xls(a_data=v_model.worksheet,a_filename='D:/_result/clustering_kmeans_mall_customers.xlsx')

# %%
v_model.columns
# Out:
# ['Age', 'AnnualIncome', 'SpendingScore']

# %%
ap.mlearn.clustering.kmeans.plot(v_model,'Age','AnnualIncome')

# %%
ap.mlearn.clustering.kmeans.plot(v_model,'Age','SpendingScore')

# %%
ap.mlearn.clustering.kmeans.plot(v_model,'AnnualIncome','SpendingScore')

# %%
ap.mlearn.clustering.kmeans.plots(v_model)

# %%
ap.mlearn.clustering.kmeans.plot3d(v_model,v_model.columns[0],v_model.columns[1],v_model.columns[2])
# Out:
# <img src="data:image/png;base64,..." width="640">
